# %% [markdown]
# # 3 — Latent Diffusion Model (LDM): generazione
#
# Secondo stadio: un **modello di diffusione latente** (`DiffusionModelUNetMaisi`, 178.566.276 parametri) addestrato **incondizionatamente** nel latente del VAE, con scheduler **Rectified Flow** (30 step di inferenza).
#
# Da rumore gaussiano l'LDM produce un latente, decodificato dal VAE in un volume `256^3`.
#
# **Interventi di questa iterazione (lato LDM):**
# - normalizzazione dei latenti **per-canale** e **centrata** — i 4 canali hanno statistiche molto eterogenee (deviazioni standard che variano di ~3.6x, una media a -3.5), che uno `scale_factor` scalare globale non condizionava correttamente;
# - campionamento **logit-normale** dei timestep in training (loc=0.0, scale=1.0), che concentra la capacita' sui timestep intermedi, i piu' difficili;
# - **autoguidance** al sampling: il modello selezionato viene guidato da una sua versione precoce (`v = v_bad + w*(v_good - v_bad)`, w=2.0). Sostituisce la CFG, non applicabile a un modello incondizionato.
#
# Visualizziamo alcuni dei 100 campioni in `data/synthetic_v4/`.

# %%
import os, sys, json, glob
ROOT=os.path.abspath("..")
if ROOT not in sys.path:
    sys.path.insert(0, ROOT)
os.chdir(ROOT)

import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

def show_ortho(vol, title=None, ax_row=None, cmap="gray"):
    """Mostra le 3 viste ortogonali (centrali) di un volume 3D."""
    if hasattr(vol, "numpy"):
        vol=vol.numpy()
    vol=np.asarray(vol).squeeze()
    x, y, z=[s // 2 for s in vol.shape]
    views=[(np.rot90(vol[x, :, :]), "Sagittale"),
             (np.rot90(vol[:, y, :]), "Coronale"),
             (np.rot90(vol[:, :, z]), "Assiale")]
    axes=ax_row if ax_row is not None else plt.subplots(1, 3, figsize=(12, 4))[1]
    for a, (img, name) in zip(axes, views):
        a.imshow(img, cmap=cmap); a.set_title(name); a.axis("off")
    if title and ax_row is None:
        plt.suptitle(title); plt.tight_layout()
    return axes

# %% [markdown]
# ## Esempi di MRI sintetiche

# %%
synth_files=sorted(glob.glob("data/synthetic_v4/hc_synth_*.nii.gz"))
print(f"{len(synth_files)} volumi sintetici disponibili")

n_show=4
fig, axes=plt.subplots(n_show, 3, figsize=(12, 4*n_show))
for r in range(n_show):
    vol=nib.load(synth_files[r]).get_fdata()
    show_ortho(vol, ax_row=axes[r])
plt.suptitle("Campioni sintetici generati dall'LDM (con autoguidance, w=2.0)", y=1.003)
plt.tight_layout(); plt.show()
# Out:
# 100 volumi sintetici disponibili

# %% [markdown]
# ## Diversita' dei campioni
# Slice assiale di molti campioni: verifica visiva dell'assenza di *mode collapse*.

# %%
n_grid=min(16, len(synth_files))
cols=4; rows=(n_grid+cols-1)//cols
fig, axes=plt.subplots(rows, cols, figsize=(3*cols, 3*rows))
for i, ax in enumerate(axes.flat):
    if i<n_grid:
        vol=nib.load(synth_files[i]).get_fdata()
        z=vol.shape[2]//2
        ax.imshow(np.rot90(vol[:,:,z]), cmap="gray")
        ax.set_title(f"#{i+1}", fontsize=8)
    ax.axis("off")
plt.suptitle("Slice assiale centrale di 16 campioni sintetici (diversita')", y=1.005)
plt.tight_layout(); plt.show()

# %% [markdown]
# **Osservazione.** I campioni mostrano anatomia riconoscibile e **variano** tra loro (ventricoli, solchi, proporzioni): nessun mode collapse evidente (conferma quantitativa nel notebook 4 via MS-SSIM).
#
# La corteccia presenta giri e solchi con bordi definiti e un confine grigia/bianca netto. Rispetto alla configurazione precedente — dove i campioni mostravano una foschia diffusa che *non* compariva nelle ricostruzioni del VAE (cfr. notebook 2) — l'**autoguidance** ha rimosso gran parte di quel difetto, agendo sul campo vettoriale appreso e non sulla discretizzazione dell'integrazione ODE (gli step restano 30).
#
# Il piano **sagittale** resta il piu' impegnativo (cervelletto leggermente meno definito), ma il divario rispetto agli altri piani si e' fortemente ridotto: nel notebook 4 il FID YZ dista ~1 punto da XY, contro i ~6 punti della configurazione senza guida.
